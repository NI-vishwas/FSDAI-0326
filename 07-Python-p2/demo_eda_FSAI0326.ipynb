# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/house_price_prediction.csv')

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
df.head(3)
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746

# %%
df.tail()
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# 1995     No  295620
# 1996    Yes  580929
# 1997     No  476925
# 1998    Yes  161119
# 1999     No  482525

# %%
df.isna().sum()
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
d1 = {
    'names': ['Alice','Bob','Claire'],
    'ages': [25,None,27],
    'gender': ['Female','Male','Female']
}

# %%
df1 = pd.DataFrame(d1)

# %%
df1.head()
# Out:
#     names  ages  gender
# 0   Alice    25  Female
# 1     Bob    30    Male
# 2  Claire    27  Female

# %%
df1.isna().sum()
# Out:
# names     0
# ages      1
# gender    0
# dtype: int64

# %%
df2 = df1['ages'].dropna()

# %%
df2.head()
# Out:
# 0    25.0
# 2    27.0
# Name: ages, dtype: float64

# %%
# Unique values in locations
df['Location'].unique()
# Out:
# array(['Downtown', 'Suburban', 'Urban', 'Rural'], dtype=object)

# %%
df['Price'].max()
# Out:
# 999656

# %%
df.describe()
# Out:
#                 Id         Area     Bedrooms   Bathrooms       Floors  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   1000.500000  2786.209500     3.003500     2.55250     1.993500
# std     577.494589  1295.146799     1.424606     1.10899     0.809188
# min       1.000000   501.000000     1.000000     1.00000     1.000000
# 25%     500.750000  1653.000000     2.000000     2.00000     1.000000
# 50%    1000.500000  2833.000000     3.000000     3.00000     2.000000
# 75%    1500.250000  3887.500000     4.000000     4.00000     3.000000
# max    2000.000000  4999.000000     5.000000     4.00000     3.000000
#
#          YearBuilt          Price
# count  2000.000000    2000.000000
# mean   1961.446000  537676.855000
# std      35.926695  276428.845719
# min    1900.000000   50005.000000
# 25%    1930.000000  300098.000000
# 50%    1961.000000  539254.000000
# 75%    1993.000000  780086.000000
# max    2023.000000  999656.000000

# %%
df['Condition'].value_counts()
# Out:
# Condition
# Fair         521
# Excellent    511
# Poor         507
# Good         461
# Name: count, dtype: int64

# %%
# Average Price by each location
avg_price_by_location = df.groupby('Location')['Price'].mean()

# %%
# Plotting average price by location
avg_price_by_location.plot(kind='bar', title='Average Price by Location')
plt.xlabel('Location')
plt.show()

# %%
print(avg_price_by_location)
# Out:
# Location
# Downtown    536059.661290
# Rural       538613.943038
# Suburban    557416.333333
# Urban       518963.548454
# Name: Price, dtype: float64

# %%
avg_price_by_location['Location'] = avg_price_by_location.index

# %%
plt.figure(figsize=(10,6))
plt.plot(['apple','mango','grapes','guava'],[10,20,30,40], 'r-x')
plt.xlabel('Fruits')
plt.ylabel('Average Price')
plt.title('Average Price of Fruits')
plt.show()
