# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
d1 = {
    "ages": [10,20,30,40]
}

# %%
s1 = pd.Series(d1)
print(s1)
# Out:
# ages    [10, 20, 30, 40]
# dtype: object

# %%
type(s1)
# Out:
# pandas.Series

# %%
d2 = {
    "name":["vishwas","bob","john"],
    "city":["bangalore", "pune","delhi"],
    "salary":[20000,40000,30000]
}

# %%
df = pd.DataFrame(d2)
df.head()
# Out:
#       name       city  salary
# 0  vishwas  bangalore   20000
# 1      bob       pune   40000
# 2     john      delhi   30000

# %%
d3 = {
    "name":["vishwas","bob","john", "Rita","Smith"],
    "city":["bangalore", None,"delhi","kashmir",None],
    "salary":[20000,np.nan,30000,"20000",None]
}

# %%
df = pd.DataFrame(d3)
df.head()
# Out:
#       name       city salary
# 0  vishwas  bangalore  20000
# 1      bob        NaN    NaN
# 2     john      delhi  30000
# 3     Rita    kashmir  20000
# 4    Smith        NaN   None

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      str
#  1   city    3 non-null      str
#  2   salary  3 non-null      object
# dtypes: object(1), str(2)
# memory usage: 297.0+ bytes

# %%
df['city'].isna().sum()
# Out:
# np.int64(2)

# %%
df_city = df["city"].fillna("UNKNOWN")
df_city.head()
# Out:
# 0    bangalore
# 1      UNKNOWN
# 2        delhi
# 3      kashmir
# 4      UNKNOWN
# Name: city, dtype: str

# %%
df_new = df.copy()
df_new["city"] = df_city
df_new.head()
# Out:
#       name       city salary
# 0  vishwas  bangalore  20000
# 1      bob    UNKNOWN    NaN
# 2     john      delhi  30000
# 3     Rita    kashmir  20000
# 4    Smith    UNKNOWN   None

# %%
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      str
#  1   city    5 non-null      str
#  2   salary  3 non-null      object
# dtypes: object(1), str(2)
# memory usage: 310.0+ bytes
