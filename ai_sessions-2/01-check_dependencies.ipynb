# %% [markdown]
# Check all the dependencies

# %%
from dotenv import load_dotenv
from env_utils import doublecheck_env, doublecheck_pkgs

# Load environment variables from .env
load_dotenv()

# Check and print results
doublecheck_env("example.env")  # check environmental variables
doublecheck_pkgs(pyproject_path="pyproject.toml", verbose=True)   # check packages
# Out:
# OPENAI_API_KEY=****here
# LANGSMITH_API_KEY=****here
# LANGSMITH_TRACING=true
# LANGSMITH_PROJECT=****ials
# Python 3.12.12 satisfies requires-python: >=3.11,<3.14
# package                | required | installed | status    | path
# ---------------------- | -------- | --------- | --------- | ------------------------------------------------------------------
# langgraph              | >=1.0.0  | 1.2.11    | ✅ OK      | /home/vishwas/.pyenv/versions/3.12.12/lib/python3.12/site-packages
# langchain              | >=1.3.10 | 1.3.10    | ✅ OK      | /home/vishwas/.pyenv/versions/3.12.12/lib/python3.12/site-packages
# langchain-core         | >=1.4.0  | 1.6.3     | ✅ OK      | /home/vishwas/.pyenv/versions/3.12.12/lib/python3.12/site-packages
# langchain-openai       | >=1.1.14 | 1.6.2     | ✅ OK      | /home/vishwas/.pyenv/versions/3.12.12/lib/python3.12/site-packages
# langchain-anthropic    | >=1.4.6  | -         | ❌ Missing | -
# sqlalchemy             | >=2.0    | 2.0.49    | ✅ OK      | /home/vishwas/.pyenv/versions/3.12.12/lib/python3.12/site-packages
# jupyter                | >=1.0.0  | -         | ❌ Missing | -
# langgraph-cli          | >=0.4.0  | 0.4.31    | ✅ OK      | /home/vishwas/.pyenv/versions/3.12.12/lib/python3.12/site-packages
# langchain-mcp-adapters | (any)    | 0.3.2     | ✅ OK      | /home/vishwas/.pyenv/versions/3.12.12/lib/python3.12/site-packages
# langchain-ollama       | >=1.0.1  | -         | ❌ Missing | -
#
# Issues detected:
# - langchain-anthropic: ❌ Missing (required >=1.4.6, installed -, path -)
# - jupyter: ❌ Missing (required >=1.0.0, installed -, path -)
# - langchain-ollama: ❌ Missing (required >=1.0.1, installed -, path -)
#
# Environment:
# - Executable: /home/vishwas/.pyenv/versions/3.12.12/bin/python
